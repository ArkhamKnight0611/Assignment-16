# %%
import pandas as pd

# %%
d=pd.Series([4,8,15,16,23,42])
d
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
a=pd.Series([4,8,15,16,23,42,7,90,65,32])
a
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# 6     7
# 7    90
# 8    65
# 9    32
# dtype: int64

# %%
data={"Name":["Alice","Bob","Claire"],
      "Age":[25,30,27],
      "Gender":["Female","Male","Female"]}
df=pd.DataFrame(data)
df
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %%
"""
Dimensions
The dimensions of the data are where a Pandas Series and a single-column DataFrame most obviously diverge. A Series only has one data column, whereas a single-column DataFrame contains both a data column and an index. The labels for the data are contained in the index, which is a second column.
Functionality
There are certain distinctions in the extra features that a Series and a single-column DataFrame offer, despite the fact that they share many common functionalities. Additional features like filtering, merging, and joining is accessible in a single-column DataFrame but not in a Series.
Data Alignment
Based on the index labels, a Pandas Series can be aligned with another Series or DataFrame. Even if the index labels are ordered differently, the alignment makes sure the data is correctly matched. Data alignment is also supported in a single-column DataFrame, but it is determined by the column label.
Performance
For actions that only involve one column of data, a Series performs more quickly than a single-column DataFrame. This is so because a Series has a more straightforward structure than a DataFrame with one column."""
# Out:
# '\nDimensions\nThe dimensions of the data are where a Pandas Series and a single-column DataFrame most obviously diverge. A Series only has one data column, whereas a single-column DataFrame contains both a data column and an index. The labels for the data are contained in the index, which is a second column.\nFunctionality\nThere are certain distinctions in the extra features that a Series and a single-column DataFrame offer, despite the fact that they share many common functionalities. Additional features like filtering, merging, and joining is accessible in a single-column DataFrame but not in a Series.\nData Alignment\nBased on the index labels, a Pandas Series can be aligned with another Series or DataFrame. Even if the index labels are ordered differently, the alignment makes sure the data is correctly matched. Data alignment is also supported in a single-column DataFrame, but it is determined by the column label.\nPerformance\nFor actions that only involve one column of data, 
# ...

# %%
a1=[1000,2000,3000,4000,5000]
d1=pd.Series(a1)
d2=pd.DataFrame(a1)

# %%
d1
# Out:
# 0    1000
# 1    2000
# 2    3000
# 3    4000
# 4    5000
# dtype: int64

# %%
d2
# Out:
#       0
# 0  1000
# 1  2000
# 2  3000
# 3  4000
# 4  5000

# %%
"""
head() and tail(): These functions allow you to view the first or last n rows of a DataFrame, which is useful for quickly inspecting data.
df.head(5)  # View the first 5 rows of the DataFrame
df.tail(3)  # View the last 3 rows of the DataFrame

info(): Provides a summary of the DataFrame, including data types and non-null counts, which helps in understanding the data's structure.
df.info()

describe(): Generates summary statistics for numerical columns, such as mean, median, min, max, and quartiles.
df.describe()

shape: Returns a tuple representing the dimensions (rows, columns) of the DataFrame.
df.shape

columns: Returns a list of column names in the DataFrame.
df.columns

value_counts(): Counts unique values in a specific column, which is useful for understanding the distribution of categorical data.
df['Category'].value_counts()

filter(): Allows you to filter rows based on a condition.
df[df['Age'] > 30]  # Filter rows where Age is greater than 30

sort_values(): Sorts the DataFrame by one or more columns.
df.sort_values(by='Salary', ascending=False)  # Sort by Salary in descending order

groupby(): Groups data based on one or more columns and allows you to perform aggregate operations on the groups.
df.groupby('Category')['Sales'].sum()  # Calculate total sales by category

pivot_table(): Creates a pivot table, which is useful for reshaping data and performing cross-tabulations.
pivot_df = df.pivot_table(index='Date', columns='Category', values='Sales', aggfunc='sum')

apply(): Applies a custom function to each element or column in the DataFrame.
df['Discounted_Price'] = df['Price'].apply(lambda x: x * 0.9)  # Apply a 10% discount to prices

merge() and join(): Combines two or more DataFrames based on common columns or indices.
merged_df = df1.merge(df2, on='Common_Column')
"""
# Out:
# "\nhead() and tail(): These functions allow you to view the first or last n rows of a DataFrame, which is useful for quickly inspecting data.\ndf.head(5)  # View the first 5 rows of the DataFrame\ndf.tail(3)  # View the last 3 rows of the DataFrame\n\ninfo(): Provides a summary of the DataFrame, including data types and non-null counts, which helps in understanding the data's structure.\ndf.info()\n\ndescribe(): Generates summary statistics for numerical columns, such as mean, median, min, max, and quartiles.\ndf.describe()\n\nshape: Returns a tuple representing the dimensions (rows, columns) of the DataFrame.\ndf.shape\n\ncolumns: Returns a list of column names in the DataFrame.\ndf.columns\n\nvalue_counts(): Counts unique values in a specific column, which is useful for understanding the distribution of categorical data.\ndf['Category'].value_counts()\n\nfilter(): Allows you to filter rows based on a condition.\ndf[df['Age'] > 30]  # Filter rows where Age is greater than 30\n\nsort
# ...

# %%
""" Series: A Pandas Series is mutable, meaning you can modify its elements, change its size, or update values at specific indices.
DataFrame: A Pandas DataFrame is also mutable. You can add or remove columns, modify values in cells, and perform various operations to change its structure and content.
Panel: The Panel data structure used to exist in Pandas but was deprecated in version 0.25.0, and it's no longer part of the core Pandas library. Panel was a 3D data structure and was not mutable in the same way as Series and DataFrame. If you need to work with 3D data in modern Pandas, you can often use a MultiIndex DataFrame instead.
"""
# Out:
# " Series: A Pandas Series is mutable, meaning you can modify its elements, change its size, or update values at specific indices.\nDataFrame: A Pandas DataFrame is also mutable. You can add or remove columns, modify values in cells, and perform various operations to change its structure and content.\nPanel: The Panel data structure used to exist in Pandas but was deprecated in version 0.25.0, and it's no longer part of the core Pandas library. Panel was a 3D data structure and was not mutable in the same way as Series and DataFrame. If you need to work with 3D data in modern Pandas, you can often use a MultiIndex DataFrame instead.\n"

# %%
series1 = pd.Series([1, 2, 3], name='A')
series2 = pd.Series(['Alice', 'Bob', 'Charlie'], name='B')
series3 = pd.Series([25, 30, 35], name='Age')

data = {'Column_A': series1, 'Column_B': series2, 'Column_C': series3}
df = pd.DataFrame(data)
df
# Out:
#    Column_A Column_B  Column_C
# 0         1    Alice        25
# 1         2      Bob        30
# 2         3  Charlie        35
